# %%
# %matplotlib inline
import os
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
from helper_evaluation import set_all_seeds, set_deterministic, compute_confusion_matrix
from helper_train import train_model
from helper_plotting import plot_training_loss, plot_accuracy, show_examples, plot_confusion_matrix
from helper_dataset import get_dataloaders_cifar10, UnNormalize

# %%
class MyDataset(Dataset):

    def __init__(self, csv_path, transform=None):
    
        df = pd.read_csv(csv_path)
        self.img_dir = df["File Directory"]
        self.img_names = df['File Name']
        self.y = df['Class Label']
        self.transform = transform

    def __getitem__(self, index):
        img = Image.open(os.path.join(self.img_dir[index],
                                      self.img_names[index]))
        
        if self.transform is not None:
            img = self.transform(img)
        
        label = self.y[index]
        return img, label

    def __len__(self):
        return self.y.shape[0]

# %%
##########################
### SETTINGS
##########################

RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 50

set_all_seeds(RANDOM_SEED)
#set_deterministic()

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
custom_transform = transforms.Compose([#transforms.Lambda(lambda x: x/255.), # not necessary
    transforms.Resize((70, 70)),
    torchvision.transforms.RandomCrop((64, 64)),
    transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])


train_dataset = MyDataset(csv_path='df_train.csv',
                          transform=custom_transform)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          drop_last=True,
                          shuffle=True, # want to shuffle the dataset
                          num_workers=0) # number processes/CPUs to use


valid_dataset = MyDataset(csv_path='df_val.csv',
                          transform=custom_transform)

valid_loader = DataLoader(dataset=valid_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=0)


test_dataset = MyDataset(csv_path='df_test.csv',
                         transform=custom_transform)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=True,
                         num_workers=0)

# %% [markdown]
# # VGG16

# %%
class VGG16(torch.nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        
        self.block_1 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=3,
                                out_channels=64,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=64,
                                out_channels=64,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        self.block_2 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=64,
                                out_channels=128,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=128,
                                out_channels=128,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        self.block_3 = torch.nn.Sequential(        
                torch.nn.Conv2d(in_channels=128,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.Conv2d(in_channels=256,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=256,
                                out_channels=256,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        self.block_4 = torch.nn.Sequential(   
                torch.nn.Conv2d(in_channels=256,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),        
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))
        )
        self.block_5 = torch.nn.Sequential(
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),            
                torch.nn.Conv2d(in_channels=512,
                                out_channels=512,
                                kernel_size=(3, 3),
                                stride=(1, 1),
                                padding=1),
                torch.nn.ReLU(),    
                torch.nn.MaxPool2d(kernel_size=(2, 2),
                                   stride=(2, 2))             
        )
        height, width = 3, 3 ## you may want to change that depending on the input image size
        self.classifier = torch.nn.Sequential(
            torch.nn.Linear(512*height*width, 4096),
            torch.nn.ReLU(True),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(4096, 4096),
            torch.nn.ReLU(True),
            torch.nn.Dropout(p=0.5),
            torch.nn.Linear(4096, num_classes),
        )
        
        for m in self.modules():
            if isinstance(m, torch.torch.nn.Conv2d) or isinstance(m, torch.torch.nn.Linear):
                torch.nn.init.kaiming_uniform_(m.weight, mode='fan_in', nonlinearity='relu')
                if m.bias is not None:
                    m.bias.detach().zero_()
                    
        self.avgpool = torch.nn.AdaptiveAvgPool2d((height, width))
        
    def forward(self, x):

        x = self.block_1(x)
        x = self.block_2(x)
        x = self.block_3(x)
        x = self.block_4(x)
        x = self.block_5(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1) # flatten
        
        logits = self.classifier(x)
        #probas = F.softmax(logits, dim=1)

        return logits

# %%
model = VGG16(num_classes=2)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)

minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)

plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([80, 100])
plt.show()
# Out:
# Epoch: 001/050 | Batch 0000/0039 | Loss: 1.3300
# Epoch: 001/050 | Train: 90.56% | Validation: 90.88%
# Time elapsed: 1.10 min
# Epoch: 002/050 | Batch 0000/0039 | Loss: 0.3086
# Epoch: 002/050 | Train: 92.92% | Validation: 92.50%
# Time elapsed: 2.18 min
# Epoch: 003/050 | Batch 0000/0039 | Loss: 0.1858
# Epoch: 003/050 | Train: 94.97% | Validation: 95.50%
# Time elapsed: 3.25 min
# Epoch: 004/050 | Batch 0000/0039 | Loss: 0.2022
# Epoch: 004/050 | Train: 94.54% | Validation: 95.37%
# Time elapsed: 4.32 min
# Epoch: 005/050 | Batch 0000/0039 | Loss: 0.1173
# Epoch: 005/050 | Train: 96.50% | Validation: 97.00%
# Time elapsed: 5.39 min
# Epoch: 006/050 | Batch 0000/0039 | Loss: 0.0802
# Epoch: 006/050 | Train: 96.63% | Validation: 97.12%
# Time elapsed: 6.45 min
# Epoch: 007/050 | Batch 0000/0039 | Loss: 0.0707
# Epoch: 007/050 | Train: 97.86% | Validation: 97.50%
# Time elapsed: 7.52 min
# Epoch: 008/050 | Batch 0000/0039 | Loss: 0.1158
# Epoch: 008/050 | Train: 98.26% | Validation: 98.62%
# Time elapsed: 8.62 min
# Epoch: 009/050 | Batch 0000/0039 | Loss: 0.0687
# Epoch: 009/050 | Train: 97.41% | Validation: 97.38%
# Time elapsed: 9.71 min
# Epoch: 010/050 | Batch 0000/0039 | Loss: 0.0860
# Epoch: 010/050 | Train: 98.03% | Validation: 98.12%
# Time elapsed: 10.77 min
# Epoch: 011/050 | Batch 0000/0039 | Loss: 0.0301
# Epoch: 011/050 | Train: 98.69% | Validation: 98.88%
# Time elapsed: 11.84 min
# Epoch: 012/050 | Batch 0000/0039 | Loss: 0.0283
# Epoch: 012/050 | Train: 98.16% | Validation: 98.50%
# Time elapsed: 12.91 min
# Epoch: 013/050 | Batch 0000/0039 | Loss: 0.0473
# Epoch: 013/050 | Train: 99.16% | Validation: 99.00%
# Time elapsed: 13.99 min
# Epoch: 014/050 | Batch 0000/0039 | Loss: 0.0255
# Epoch: 014/050 | Train: 99.51% | Validation: 99.38%
# Time elapsed: 15.05 min
# Epoch: 015/050 | Batch 0000/0039 | Loss: 0.0303
# Epoch: 015/050 | Train: 98.70% | Validation: 99.00%
# Time elapsed: 16.11 min
# Epoch: 016/050 | Batch 0000/0039 | Loss: 0.0130
# Epoch: 016/050 | Train: 99.46% | Validation: 99.38%
# Time elapsed: 17.19 min
# Epoch: 017/050 | Batch 0000/0039 | Loss: 0.0258
# Epoch: 017/050 | Train: 98.46% | Validation: 98.50%
# Time elapsed: 18.28 min
# Epoch: 018/050 | Batch 0000/0039 | Loss: 0.0216
# Epoch: 018/050 | Train: 99.54% | Validation: 99.50%
# Time elapsed: 19.36 min
# Epoch: 019/050 | Batch 0000/0039 | Loss: 0.0167
# Epoch: 019/050 | Train: 99.74% | Validation: 99.38%
# Time elapsed: 20.43 min
# Epoch: 020/050 | Batch 0000/0039 | Loss: 0.0081
# Epoch: 020/050 | Train: 99.67% | Validation: 99.38%
# Time elapsed: 21.50 min
# Epoch: 021/050 | Batch 0000/0039 | Loss: 0.0169
# Epoch: 021/050 | Train: 99.86% | Validation: 99.62%
# Time elapsed: 22.57 min
# Epoch: 022/050 | Batch 0000/0039 | Loss: 0.0073
# Epoch: 022/050 | Train: 99.73% | Validation: 99.50%
# Time elapsed: 23.64 min
# Epoch: 023/050 | Batch 0000/0039 | Loss: 0.0102
# Epoch: 023/050 | Train: 99.73% | Validation: 99.62%
# Time elapsed: 24.70 min
# Epoch: 024/050 | Batch 0000/0039 | Loss: 0.0028
# Epoch: 024/050 | Train: 99.71% | Validation: 99.50%
# Time elapsed: 25.77 min
# Epoch: 025/050 | Batch 0000/0039 | Loss: 0.0445
# Epoch: 025/050 | Train: 99.85% | Validation: 99.88%
# Time elapsed: 26.83 min
# Epoch: 026/050 | Batch 0000/0039 | Loss: 0.0043
# Epoch: 026/050 | Train: 99.88% | Validation: 99.62%
# Time elapsed: 27.91 min
# Epoch: 027/050 | Batch 0000/0039 | Loss: 0.0028
# Epoch: 027/050 | Train: 99.86% | Validation: 99.62%
# Time elapsed: 28.98 min
# Epoch: 028/050 | Batch 0000/0039 | Loss: 0.0020
# Epoch: 028/050 | Train: 99.86% | Validation: 99.25%
# Time elapsed: 30.05 min
# Epoch: 029/050 | Batch 0000/0039 | Loss: 0.0260
# Epoch: 029/050 | Train: 99.94% | Validation: 99.75%
# Time elapsed: 31.13 min
# Epoch: 030/050 | Batch 0000/0039 | Loss: 0.0030
# Epoch: 030/050 | Train: 99.97% | Validation: 99.75%
# Time elapsed: 32.21 min
# Epoch: 031/050 | Batch 0000/0039 | Loss: 0.0078
# Epoch: 031/050 | Train: 99.88% | Validation: 99.38%
# Time elapsed: 33.28 min
# Epoch: 032/050 | Batch 0000/0039 | Loss: 0.0030
# Epoch: 032/050 | Train: 99.79% | Validation: 99.50%
# Time elapsed: 34.35 min
# Epoch: 033/050 | Batch 0000/0039 | Loss: 0.0100
# Epoch: 033/050 | Train: 99.55% | Validation: 98.75%
# Time elapsed: 35.43 min
# Epoch: 034/050 | Batch 0000/0039 | Loss: 0.0057
# Epoch: 034/050 | Train: 99.98% | Validation: 99.75%
# Time elapsed: 36.50 min
# Epoch: 035/050 | Batch 0000/0039 | Loss: 0.0014
# Epoch: 035/050 | Train: 99.87% | Validation: 99.25%
# Time elapsed: 37.58 min
# Epoch: 036/050 | Batch 0000/0039 | Loss: 0.0009
# Epoch: 036/050 | Train: 99.97% | Validation: 99.75%
# Time elapsed: 38.66 min
# Epoch    36: reducing learning rate of group 0 to 1.0000e-03.
# Epoch: 037/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 037/050 | Train: 99.99% | Validation: 99.75%
# Time elapsed: 39.74 min
# Epoch: 038/050 | Batch 0000/0039 | Loss: 0.0012
# Epoch: 038/050 | Train: 99.98% | Validation: 99.50%
# Time elapsed: 40.81 min
# Epoch: 039/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 039/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 41.88 min
# Epoch: 040/050 | Batch 0000/0039 | Loss: 0.0010
# Epoch: 040/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 42.95 min
# Epoch: 041/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 041/050 | Train: 100.00% | Validation: 99.62%
# Time elapsed: 44.02 min
# Epoch: 042/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 042/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 45.09 min
# Epoch: 043/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 043/050 | Train: 100.00% | Validation: 99.38%
# Time elapsed: 46.16 min
# Epoch: 044/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 044/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 47.23 min
# Epoch: 045/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 045/050 | Train: 100.00% | Validation: 99.62%
# Time elapsed: 48.30 min
# Epoch: 046/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 046/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 49.37 min
# Epoch: 047/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 047/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 50.44 min
# Epoch    47: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 048/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 048/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 51.51 min
# Epoch: 049/050 | Batch 0000/0039 | Loss: 0.0006
# Epoch: 049/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 52.59 min
# Epoch: 050/050 | Batch 0000/0039 | Loss: 0.0007
# Epoch: 050/050 | Train: 100.00% | Validation: 99.50%
# Time elapsed: 53.65 min
# Total Training Time: 53.65 min
# Test accuracy 99.50%

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'Without',
              1: 'With'
              }

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()
